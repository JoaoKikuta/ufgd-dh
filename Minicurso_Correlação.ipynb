# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoKikuta/ufgd-dh/blob/main/Minicurso_Correla%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análise de Correlação Simples**

# %% [markdown]
# ##O que é?
#
# Estudar a relação entre duas variáveis (X, y)
#
# X: Dependente
#
# Y: Independente
#
# Atráves do coeficiente de Pearson, podemos analisar a força ou Relação entre as Variáveis.
#
# Coeficiente entre -1 a +1
# Quanto mais próximo de |1| mais forte
#
#
# *   C > 0 : Correlação Positiva
# *   C = 0 : Correlação Nula
# *   C < 0 : Correlação Negativa

# %% [markdown]
# Diagrama de Dispersão
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Análise

# %% [markdown]
# ### **Importar Bibliotecas**

# %% [markdown]
# ### **Importar os dados**

# %% [markdown]
# ### **Visualizar os dados**

# %% [markdown]
# ### **Análise de Correlação**

# %% [markdown]
# ### **Análise de Correlação sem 2019**
